# %% [markdown]
# # <font color="#3A40A2">📘 Introducción a Google Colab y su rol en el curso</font>
#
#
# **Materia: Ciencia de Datos aplicada a los Negocios - Universidad de San Andrés**
#
# **Autor: [Lucas BALDEZZARI](https://www.linkedin.com/in/lucasbaldezzari/)**
#
# **2026**
#
# > Este material es para fines educativos y no debe ser utilizado para fines comerciales. El contenido pertenece a la *Universidad de San Andrés* y no debe ser reproducido sin el permiso explícito de la institución y del autor de este repositorio quien es [LUCAS BALDEZZARI](https://www.linkedin.com/feed/).
# ---

# %% [markdown]
# ### <font color="#004eb3">Empezando con Google Colab</font>
#
# Antes de empezar con el contenido de la materia, vamos a conocer la herramienta principal que utilizaremos a lo largo del curso para poner en práctica lo que vayamos viendo en la teoría.
#
# La herramienta se llama **Google Colab**.

# %% [markdown]
# ### <font color="#004eb3">¿Qué es Google Colab?</font>
#
# Google Colab -abreviatura de "*Google Colaboratory*"- es una plataforma gratuita de Google que permite escribir y ejecutar código en lenguaje Python directamente desde tu navegador. No requiere instalación, no requiere configurar nada y funciona desde cualquier computadora con acceso a internet.
#
# Esta herramienta es muy útil para:
#
# - **No es necesario saber programar para usarlo**
# - Podemos escribir texto, agregar imágenes y gráficos explicativos, además de código, claro. Esto es muy potente, dado que podemos agregar nuestros propios apuntes y así usarlo a futuro.
# - Se puede compartir y colaborar en tiempo real.
# - Está enfocado para **análisis de datos, visualización y machine learning**.

# %% [markdown]
# ### <font color="#004eb3">¿Para qué lo vamos a usar en este curso?</font>
#
#
# 1. **Visualizar conceptos vistos en clases de teoría** a través de ejemplos gráficos y explicaciones guiadas.
# 2. **Analizar** datos reales y ficticios asociados a los negocios.
# 3. **Aplicar algoritmos de aprendizaje no supervisado**, entre otros conceptos.
# 4. **Entrenar modelos para reducción de dimensionalidad**.
# 5. **Combinar** lo visto en el curso para resolver un problema asociado a los negocios.
#
# Y finalmente, usar cada Colab como **material de estudio**.

# %% [markdown]
# Algunas ventajas de usar Colabs
#
# | Ventaja                     | ¿Por qué es útil para este curso?                                         |
# | --------------------------- | ------------------------------------------------------------------------- |
# | **Accesibilidad**           | *No hay que instalar nada*. Solo se necesita una cuenta de Gmail (se recomienda usar la de UdeSA).           |
# | **Entorno seguro y simple** | Ideal para quienes nunca han programado.        |
# | **Visualización clara**     | Podemos mezclar texto, gráficos e interactividad, haciendo el entorno explicativo.             |
# | **Ejemplos guiados**        | Todo el contenido estará preparado para que sigas paso a paso.            |
# | **Adaptado a la práctica**  | Usaremos conjuntos de datos simulados o reales del mundo de los negocios. |

# %% [markdown]
# ### 🛑 <font color="#004eb3">¿Es necesario saber programar?</font>  🛑
#
# <font color="#00b351">**NO es necesario saber programar** 😀</font>.
#
# Todo el contenido que veremos en las Colbas *está pensado para personas sin experiencia previa en programación*. Usaremos el mínimo de código posible, acompañado siempre de explicaciones claras y ejemplos visuales.
#
# La idea, insisto, no es aprender a programar, sino aprender los conceptos asociados al curso.
#
# Sin embargo, aquellas personas interesadas en

# %% [markdown]
# ### <font color="#004eb3">Partes de una Google Colab</font>
#
# A contunuación se muestran las partes principales de la Google Colab que usaremos en este curso.
#
# #### **<font color="#d6b302">Celdas</font>**
#
# Una *celda* es simplemente un recuadro donde podemos colocar texto o código.
#
# #### **Celda de texto**
#
# Una celda de texto, como su nombre lo indica, nos permite colocar código (cómo este que estas leyendo).
#
# ¿Es posible modificar el contenido de una celda de texto? -> ¡Sí! Para hacerlo, simplemente tenes que hacer doble click y podrás editar, agregar y/o borrar lo que quieras.
#
# #### **Celda de *código***
#
# Este tipo de celdas nos permite colocar código (en lenguaje *python*) y ejecutar el mismo.
#
# *¿Cómo nos damos cuenta que es una celda de código?*
#
# En primer lugar, el color de fondo de estas celdas es ligeramente diferente a las celdas de texto. En segundo lugar, es altamente probable que te des cuenta que se trata de código porque verás cosas como la siguiente:
#
# ```python
# ## **** CÓDIGO PYTHON ****
#
# from cdan.funciones import tests
# tests.transform_and_get_iris()
# ```
#
# Es importante recordar **que no es necesario entender qué hace el código** dado que no es objetivo del curso aprender a programar, no obstante, es a través de programación que se analizan datos, se generan gráficos, tablas para analizar y entrenar modelos de Machine Learning (entre muchas cosas más).

# %% [markdown]
# ### <font color="#004eb3">Paso a paso para ejecutar una celda de código</font>
#
# Veamos un ejemplo de uso.
#
# **IMPORTANTE**: En primer lugar, una colab siempre se lee y ejecuta **desde el inicio hacia el final**, es decir, para que funcione correctamente cada parte de la herramienta es necesario ejecutar cada celda de código, **una a la vez y desde el inicio hacia el final**. Es importante no saltarse ninguna celda.
#
#
# ¿Cómo ejecutamos una celda de código?
#
# La siguiente imagen muestra el paso a paso de cómo ejecutar una celda de código.
#
# <p align="center">
#   <img src="https://github.com/lucasbaldezzari/cdan/raw/main/imagenes/colab_intro/ejecucion_celda_codigo.png" width="640"/>
# </p>
#
# **ALTERNATIVA**. Presionar *Run all*.

# %% [markdown]
# ## <font color="#00b351">Ejemplo de uso de una colab</font>
#
# A continuación, veamos un ejemplo sencillo para entender cómo ejecutar una celda de código.
#
# En este caso, la salida final mostrará dos gráficos de dispersión, los cuales muestran el antes y el después de agrupar un set de datos que utlizaremos de ejemplo en varios momentos del cursado.

# %% [markdown]
# ### <font color="#00b351">PASO 1</font>
#
# Para todas las prácticas que realizaremos en el curso, el primer paso es clonar el [respositorio](https://github.com/lucasbaldezzari/cdan) donde se alojan funciones, imágenes y set de datos que usaremos para trabajar.
#
# <font color="#eb4034">Debemos ejecutar la celda que se muestra abajo antes de cualquier otra.</font> La clonación puede tardar uno o dos minutos, por favor, se paciente.

# %%
## **** CÓDIGO PYTHON ****

##Clonamos el repositorio para poder usar las funciones
# !git clone https://github.com/lucasbaldezzari/cdan.git

# %% [markdown]
# ### <font color="#00b351">PASO 2: Revisar que el repositorio se ha clonado</font>
#
# Una vez que se termina de ejecutar la celda anterior, es una buena práctica revisar que el repositorio se haya clonado. Para esto, debemos hacer click Archivos (o Files si lo tenes en inglés) que se encuentra a la izquierda en el panel de herramientas.
#
# Deberíamos ver una carpeta llamada *cdan* con una estructura de archivos y carpetas similar a la de la foto de abajo.

# %% [markdown]
# ### <font color="#00b351">PASO 3: Empezar a ejecutar el resto de las celdas</font>
#
# Una vez que hemos clonado y verificado que la clonación fue exitosa, ya podemos empezar a ejecutar las siguientes celdas de la colab.
#
# **RECOMENDACIÓN:** Se recomienda ejecutar cada celda en orden, es decir, no saltearse celdas.

# %%
from cdan.funciones import utils ##importo funciones a usar
from cdan.funciones import intro_colab ##importo graficos a usar

data = utils.transform_and_get_iris().drop(columns="segmento")
##entreno Kmeans para 3 clusters
from sklearn.cluster import KMeans
kmeans = KMeans(n_clusters=3, random_state=42)

kmeans.fit(data) ##entrenamos el modelo
labels = kmeans.labels_ ##etiquetas obtenidas por el modelo
centros = kmeans.cluster_centers_ ##centros de los clusters

intro_colab.plotExample1(data, labels,centros,(8,5))

# %% [markdown]
# ### Gráfico interactivo
#
# En ocasiones podremos generar gráficos interactivos como el que se muestra debajo. Veamos.

# %%
import plotly.io as pio

pio.renderers.default = 'colab'
intro_colab.plotExample2(data, labels, centros, (8, 5))

# %% [markdown]
# #### **<font color="#d6b302">Resultado</font>**
#
# Como podemos ver, luego de ejecutar las dos celdas de código anterior hemos generado una figura con dos gráficos. El gráfico de la izquierda muestra la distribución de datos (puntos) del set de datos. El gráfico de la derecha, por otro lado, representa el agrupamiento realizado con K-means. Podemos ver que el algoritmo ha generado tres grupos.
#
# Aprenderemos más acerca de cómo se han agrupado los puntos originales en la clase *Algoritmos básicos para clustering* 👌.

# %% [markdown]
# ### 🛑 <font color="#ff0000">IMPORTANTE</font>  🛑
#
# Para evitar errores cuando estemos ejecutando y probando el código de la colab, es **sumamente importante** generar una copia de la misma.
#
# Para esto, lo que haremos es ir al menú *Archivo* (File), luego a *Guardar una copia en Drive* (Save a copy in Drive).

# %% [markdown]
# ## <font color="#00b351">Comentarios finales</font>
#
# Hasta aquí aprendimos qué es y para qué usaremos Googel Colaboratory.
#
# Es importante recordar que es una herramienta para análisis de datos, entrenamiento de algoritmos de Machine Learning, entre otras características, que permite interactuar con el contenido.
#
# En este curso, usaremos google colab para poder mostrar ejemplos prácticos que nos permitan reforzar lo visto en clases de teoría, de una manera sencilla, pero al mismo tiempo, potente y completa.
#
# Durante las clases, el docente mostrará paso a paso cada una de las google colabs que se compartan, es decir, el/la estudiante no estará solo/a y podrá disipar cualquier duda y/o problema que pueda surgir.
#
# Finalmente, decir que las Google Colab servirán como material de estudio.

# %% [markdown]
# ---
#
#
# Saludos.
#
# *Lucas Baldezzari*
